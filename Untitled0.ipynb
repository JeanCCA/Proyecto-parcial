# %% [markdown]
# <a href="https://colab.research.google.com/github/JeanCCA/Proyecto-parcial/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
from bs4 import BeautifulSoup
import requests
import pandas as pd

print("Ingrese ID de usuario: ")
id = input()

page = requests.get("https://es.stackoverflow.com/users/"+id)
soup = BeautifulSoup(page.content,'html.parser')

try:  
  codigo = soup.find('div',class_="grid--cell fw-bold").text
    
  url = "https://es.stackoverflow.com/users/"+id+"/"+codigo+"?tab=tags" + "&sort=votes&page="
  #---------------------------------------------------------   
  print("La nube de palabras es:") 
  try:
    def plot_cloud(wordcloud):     
      plt.figure(figsize=(6, 3), dpi=100)
      plt.imshow(wordcloud) 
      plt.axis("off");
      
    wordcloud = WordCloud(width = 3000, height = 2000, random_state=0, background_color='white', colormap='jet', 
                        collocations=False, stopwords = STOPWORDS, regexp= r"\S[\S']+" ).generate(' '.join(listacomplit))
    plot_cloud(wordcloud)

  except ValueError:
      print("Error el usuario no registra etiquetas")
     
except AttributeError:
    print("Usuario no encontrado, asegurese que el usuario exista")
# Out:
# Ingrese ID de usuario:
# 7123
# La nube de palabras es:
